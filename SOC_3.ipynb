# %%
import requests
from bs4 import BeautifulSoup as bs
import types
import re
import pymysql
import time
import sys
import json

#rewrite string to fit SQL syntax
def FixText(text):
    new_text=""
    for c in text:
        if c=='\'': new_text+="''"
        elif c=='\\': new_text+=""
        else : new_text+=c
    return new_text

#parameter: string that format is datatime
#return: interger of unixtime
def dttounix(dt):
    try:
        return int(time.mktime(time.strptime(dt, '%Y-%m-%d %H:%M:%S')))
    except:
        print('\n'+str(dt)+' is wrong format!\nShould be YYYY-MM-DD HH:MM:SS\n')
        return 0

#parameter: str/int/float of unixtime
#return: string of datatime
def unixtodt(unix):
    if type(unix) is not type(999):
        return str(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(int(unix))))
    else:
        return str(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(unix)))

#search tag_id from Tags table and save (qid,tagid) to QandTag table
#parameter: string of tags(divide by ',') and qID
#return: None
def FindTagID(tags,qID):
    split_tag=tags.split(',')
    for x in split_tag:
        command="SELECT `id` FROM `Tags` WHERE `name` = '"+x+"';"
        cursor.execute(command)
        result = cursor.fetchall()
        if result is tuple([]):
            tagID=-1 # 當出現冷僻tag時用-1填tagID?
        else:
            tagID=result[0][0]
        command="INSERT INTO `stackOverflow`.`QandTag` VALUES (NULL, '"+str(qID)+"', '"+str(tagID)+"');"
        cursor.execute(command)
def users(owner_id):
    sql="SELECT `user_id`  FROM `User` WHERE `user_id` = "+str(owner_id)#把我從question抓下來的user_id，去User table找一樣的放進res
    cursor.execute(sql)
    res=cursor.fetchall()
    if not res: #若這個user_id不在User table裡面，就開始做事
        print(owner_id,' hasn\'t recorded')
        
        #-----------------------Start---------------------------
        user_url = "https://stackoverflow.com/users/" + str(owner_id)
        user_page = bs(requests.get(user_url).text,'html.parser')

        reputation = user_page.find('div',class_='reputation').text.split(' r')[0]#可能大於一千，就會有,不能直接轉型
        reputation = int(reputation.strip().replace(',',''))

        answers = int(user_page.find('div',class_='stat answers col-3').text.split('a')[0].strip().replace(',',''))

        questions = int(user_page.find('div',class_='stat questions col-3').text.split('q')[0].strip().replace(',',''))

        reached = user_page.find('div',class_='stat people-helped col-5').text.split('p')[0].strip().replace('~','').replace(',','')
        if(reached[-1] == 'k'):
            reached = float(reached.replace('k',''))
            reached = reached * 1000
        elif(reached[-1] == 'm'):
            reached = float(reached.replace('m',''))
            reached = reached * 1000000
        else:
            reached = float(reached)

        profile = user_page.find('ul',class_='list-unstyled')
        location = ''
        age = ''
        views = ''
        for x in profile.find_all('li'):
            if(x.find('svg',class_='svg-icon iconLocation') is not None):#代表這傢伙有居住地
                location = x.text.strip()
            if(x.find('svg',class_='svg-icon iconHistory') is not None):#這傢伙的帳號創建日
                age = x.find('span')['title'].split('Z')[0]
            if(x.find('svg',class_='svg-icon iconEye') is not None):
                views = int(x.text.split(' p')[0].strip().replace(',',''))
                
        #---------Pass the values in database-----------
        cursor.execute('INSERT INTO User (user_id,reputation,answers,questions,reached,location,age,views) VALUES('
                       + '' + str(owner_id) + ',' + str(reputation) + ',' + str(answers) + ',' + str(questions) + ',' + str(reached) + ',"' + location + '","' + age + '",' + str(views) + ')')
        #-----------------End User table----------------
        
        #---------------Start UserTag table-------------
        page = 1
        total_count = 0
        total_score = 0

        while True:
            try:
                toptags_url = 'https://api.stackexchange.com/2.2/users/'+str(owner_id)+'/top-tags?page=' + str(page) + '&pagesize=100&site=stackoverflow'
                user_toptags = bs(requests.get(toptags_url).text,'html.parser')
                json_str = json.loads(user_toptags.text)

                cursor.execute('SELECT id FROM User WHERE user_id = '+str(owner_id))
                user_index = cursor.fetchall()#user_index[0][0]是int

                for x in range(len(json_str['items'])):
                    total_count = json_str['items'][x]['answer_count'] + json_str['items'][x]['question_count']#把answer和question的數量加起來
                    total_score = json_str['items'][x]['answer_score'] + json_str['items'][x]['question_score']#把answer和question的分數加起來
                    average = total_score/total_count#算平均每個問題得到幾分

                    cursor.execute('SELECT id FROM Tags WHERE name = "'+str(json_str['items'][x]['tag_name'])+'"')
                    tag_id = cursor.fetchall()

                    if tag_id:#代表這個tag存在於Tags這個table裡面
                        cursor.execute('INSERT INTO UserTag (user_index,user_id,tag_id,answer_count,answer_score,question_count,question_score,total_count,total_score,average) VALUES('
                                       +str(user_index[0][0])+','+str(owner_id)+','+str(tag_id)+','+str(json_str['items'][x]['answer_count'])+','+str(json_str['items'][x]['answer_score'])+','+str(json_str['items'][x]['question_count'])+','+str(json_str['items'][x]['question_score'])+','+str(total_count)+','+str(total_score)+','+str(average)+')')

                    #---------Pass the values in database-----------
                    
                if (json_str['has_more'] is False):#還沒結束，後面還有
                    break
                page = page + 1
            except:
                print('API爆了')
                return False
        #------------End UserTag table------------
    else:
        print(owner_id,"!!!!This id has been recoreded.!!!!")
    return True
#crawl question,comment and upload to database, inquire API if necessary
#parameter: beautyfulsoup object of one question page
#return: right answer of this question, 0 if not found
def handleQ(page):
    callAPI=False
    if page.find('span',class_='vote-accepted-on load-accepted-answer-date') is not None:
        solved="1"
        right_ans=page.find('span',class_='vote-accepted-on load-accepted-answer-date').parent.find('input')['value']
    else:
        solved="0"
        right_ans="0"
    title=page.find('h1',itemprop='name').text
    question=page.find('div',class_='question')
    qID=question['data-questionid']
    if question.find('a',href=re.compile(r'^/users/') ) is not None:
        ownerID=question.find('a',href=re.compile(r'^/users/'))['href'].split('users/')[1].split('/')[0]
    else: ownerID='0'
    if question.find('div',class_='user-action-time') is not None:
        create_time=question.find('div',class_='user-action-time').find('span')['title'].split('Z')[0]
    else: cacllAPI=True 
    if ownerID=='0' or ownerID=='-1' :
        callAPI=True
    posts=""
    for x in question.find('div',class_='post-text').children:
        posts+=str(x)
    score=question.find('span',itemprop='upvoteCount').text
    tags=""
    if question.find('div',class_='post-taglist') is not None:
        for x in question.find('div',class_='post-taglist').find_all('a'):
            if tags=="": tags=x.text
            else: tags=tags+","+x.text
    last_active_time='0000-00-00 00:00:00'
    if callAPI:
        global callCount
        callCount+=1
        APIurl="https://api.stackexchange.com/2.2/questions/"+qID+"?order=desc&sort=activity&site=stackoverflow"
        #print(' callAPI-Question')
        #print(APIurl)
        info=(requests.get(APIurl).json())['items'][0]
        if 'user_id' in info['owner']:
            ownerID=str(info['owner']['user_id'])
        else: ownerID='0'
        create_time=unixtodt(info['creation_date'])
        last_active_time=unixtodt(info['last_activity_date'])
    if not users(ownerID):
        #pen.write('API爆了')
        exit()
    add_question="INSERT INTO `stackOverflow`.`Questions` VALUES (NULL, '"+str(qID)+"', '"+FixText(title)+"', '"+tags+"', '"+ownerID+"', '"+score+"', '"+solved+"', '"+create_time+"', '"+last_active_time+"', '"+FixText(posts)+"');"
    add_comment="INSERT INTO  `stackOverflow`.`Comments` VALUES "
    #comment part
    for comm in question.find_all('li',id=re.compile(r'^comment-')):
        cID=comm["data-comment-id"]
        comment=comm.find('span',class_='comment-copy').text
        ownerID='0'
        if comm.find('a',class_=re.compile(r'^comment-user')) is not None:
            ownerID=comm.find('a',class_=re.compile(r'^comment-user'))['href'].split('users/')[1].split('/')[0]
            if not users(ownerID):
                #pen.write('API爆了')
                exit()
        if comm.find('span',class_='relativetime-clean') is not None:
            create_time=comm.find('span',class_='relativetime-clean')['title'].split('Z')[0]
        else: create_time='0000-00-00 00:00:00'
        if add_comment[-2]!='S': add_comment+=","
        add_comment+="(NULL, '"+cID+"', '"+qID+"','0','"+ownerID+"', '"+create_time+"', '"+FixText(comment)+"')"
    cursor.execute(add_question)
    if add_comment[-2]!='S': cursor.execute(add_comment+";")
    FindTagID(tags,qID)
    return right_ans

#crawl answer,comment and upload to database, inquire API if necessary
#parameter: beautyfulsoup object of one question page
#return: none
def handleA(page,right_ans):
    add_answer="INSERT INTO `stackOverflow`.`Answers`VALUES "
    for answer in page.find_all('div',id=re.compile(r'^answer-') ):
        callAPI=False
        aID=answer['data-answerid']
        if aID==right_ans: solved="1"
        else: solved="0"
        posts=""
        for x in answer.find('div',class_='post-text').children:
            posts+=str(x)
        score=answer.find('span',itemprop='upvoteCount').text
        if answer.find('a',href=re.compile(r'^/users/')) is not None:
            ownerID=answer.find('a',href=re.compile(r'^/users/'))['href'].split('users/')[1].split('/')[0]
        else: ownerID='0'
        if answer.find('div',class_='user-action-time') is not None:
            create_time=answer.find('div',class_='user-action-time').find('span')['title'].split('Z')[0]
        else: callAPI=True
        if ownerID=='0' or ownerID=='-1' :
            callAPI=True
        if callAPI:
            global callCount
            callCount+=1
            APIurl="https://api.stackexchange.com/2.2/answers/"+aID+"?order=desc&sort=activity&site=stackoverflow"
            #print(' callAPI-Answer')
            #print(APIurl)
            info=(requests.get(APIurl).json())['items'][0]
            if 'user_id' in info['owner']:
                ownerID=str(info['owner']['user_id'])
            else: ownerID='0'
            create_time=unixtodt(info['creation_date'])
        if not users(ownerID):
            #pen.write('API爆了')
            exit()
        if add_answer[-2]!='S':add_answer+=","
        add_answer+="(NULL, '"+aID+"', '"+qID+"', '"+ownerID+"', '"+score+"', '"+solved+"', '"+create_time+"', '"+FixText(posts)+"')"
        #comment part
        add_comment="INSERT INTO  `stackOverflow`.`Comments` VALUES "
        for comm in answer.find_all('li',id=re.compile(r'^comment-')):
            cID=comm["data-comment-id"]
            comment=comm.find('span',class_='comment-copy').text
            if comm.find('a',class_=re.compile(r'^comment-user')) is not None:
                ownerID=comm.find('a',class_=re.compile(r'^comment-user'))['href'].split('users/')[1].split('/')[0]
                if not users(ownerID):
                    #pen.write('API爆了')
                    exit()
            else: ownerID='0'
            if comm.find('span',class_='relativetime-clean') is not None:
                create_time=comm.find('span',class_='relativetime-clean')['title'].split('Z')[0]
            else: create_time='0000-00-00 00:00:00'
            if add_comment[-2]!='S': add_comment+=","
            add_comment+="(NULL, '"+cID+"', '"+aID+"','1','"+ownerID+"', '"+create_time+"', '"+FixText(comment)+"')"
        if add_comment[-2]!='S': cursor.execute(add_comment+";")
    if add_answer[-2]!='S': 
        cursor.execute(add_answer+";")

#use API to get list of qID
#parameter: start time,end time,min score,max score (all str type)
#return: list contain all qID (str type)
def GetqIDs(s,e,mi='0',ma=""):
    Qlist=[]
    start=dttounix(s)
    end=dttounix(e)
    page=1
    psize=100 #100 question object / page
    minscore=mi
    maxscore=ma
    while True: #one page every loop
        global callCount
        callCount+=1
        sys.stdout.write('\rloading page '+str(page))
        sys.stdout.flush()
        url="https://api.stackexchange.com/2.2/questions?page="+str(page)+"&pagesize="+str(psize)+"&fromdate="+str(start)+"&todate="+str(end)+"&order=desc&min="+str(minscore)+"&max="+str(maxscore)+"&sort=votes&site=stackoverflow"
        text=requests.get(url=url).json()
        for question in text['items']:
            qid=str(question['question_id'])
            Qlist.append(qid)
        if text["has_more"]: page+=1
        else: break
        if 'backoff' in text:
            time.sleep(text['backoff'])
    return Qlist

#main
pen=open('stack_crawler_log.txt', 'a')
try:
    me=json.loads(open('account.json',encoding = 'utf8').read().encode('utf8'))
    db=pymysql.connect(me['host'],me['username'],me['password'],me['db'],use_unicode=True,charset="utf8mb4",autocommit=True)
    cursor=db.cursor()
    callCount=0 #increase when call API
    start_time='2017-04-16 00:00:00'
    end_time='2017-04-30 23:59:59'
    min_score='20'
    log='\nProgress start at '+unixtodt(time.time())+'\nData is questions from '+start_time+' to '+end_time+' and score bigger than '+min_score
    pen.write(log)
    qIDs=GetqIDs(start_time,end_time,min_score)
except:
    log='\nAn error occur at '+unixtodt(time.time())+'\n'+str(sys.exc_info()[0])+'\n'+str(sys.exc_info()[1])+'\n Progress die.'
    pen.write(log)
    pen.close()
    db.close()
    exit()
print('\rall ',len(qIDs),' qIDs are loaded')
print('crawling data now..')
log='\nFind '+str(len(qIDs))+' questions'
pen.write(log)
counter=1
for qID in qIDs:
    try:
        url="https://stackoverflow.com/questions/"+qID
        page=bs(requests.get(url).text,'html.parser')
        right_ans=handleQ(page)
        handleA(page,right_ans)
        sys.stdout.write('\rProgress Rate: {:.2%}'.format(counter/len(qIDs)))
        sys.stdout.flush()
        counter+=1
    except:
        log='\nAn error occur at '+unixtodt(time.time())+'\n running qid: '+str(qID)+'\n'+str(sys.exc_info()[0])+'\n'+str(sys.exc_info()[1])+'\n Progress die.'
        pen.write(log)
        pen.close()
        db.close()
        exit()
db.close()
log='\nCall API '+str(callCount)+' times\nProgress Finish at '+unixtodt(time.time())+'\n'
pen.write(log)
pen.close()
exit()
# Out:
# all  95  qIDs are loaded
# crawling data now..
# 102937 !!!!This id has been recoreded.!!!!
# 3939277 !!!!This id has been recoreded.!!!!
# 100297 !!!!This id has been recoreded.!!!!
# 3939277 !!!!This id has been recoreded.!!!!
# 900873 !!!!This id has been recoreded.!!!!
# 3939277 !!!!This id has been recoreded.!!!!
# C:\Users\an94m\Anaconda3\lib\site-packages\pymysql\cursors.py:165: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x91\\xA9\\xE2\\x80...' for column 'text' at row 1")
#   result = self._query(query)
# 5389870 !!!!This id has been recoreded.!!!!
# 828854 !!!!This id has been recoreded.!!!!
# 1187415 !!!!This id has been recoreded.!!!!
# 97337  hasn't recorded
# 3397217  hasn't recorded
# 97337 !!!!This id has been recoreded.!!!!
# 3939277 !!!!This id has been recoreded.!!!!
# 1337  hasn't recorded
# 3939277 !!!!This id has been recoreded.!!!!
# 1077672  hasn't recorded
# 1077672 !!!!This id has been recoreded.!!!!
# 1077672 !!!!This id has been recoreded.!!!!
# 5838902  hasn't recorded
# Progress Rate: 1.05%3814029  hasn't recorded
# 1746118  hasn't recorded
# 4832043  hasn't recorded
# 5087125  hasn't recorded
# 188626  hasn't recorded
# 4927616  hasn't recorded
# 1554878  hasn't recorded
# 1479414  hasn't recorded
# 2804703  hasn't recorded
# 5868823  hasn't recorded
# 2422285  hasn't recorded
# 4543133  hasn't recorded
# 3523579  hasn't recorded
# 3814029 !!!!This id has been recoreded.!!!!
# 3523579 !!!!This id has been recoreded.!!!!
# 3814029 !!!!This id has been recoreded.!!!!
# 1021725  hasn't recorded
# 3523579 !!!!This id has been recoreded.!!!!
# 1479414 !!!!This id has been recoreded.!!!!
# 448779  hasn't recorded
# 2160682  hasn't recorded
# 1479414 !!!!This id has been recoreded.!!!!
# 1479414 !!!!This id has been recoreded.!!!!
# 2876079  hasn't recorded
# 2394204  hasn't recorded
# 2579220  hasn't recorded
# 2140160  hasn't recorded
# 2028066  hasn't recorded
# 2140160 !!!!This id has been recoreded.!!!!
# 8754672  hasn't recorded
# 2028066 !!!!This id has been recoreded.!!!!
# 1331310  hasn't recorded
# 9333737  hasn't recorded
# 884463  hasn't recorded
# 884463 !!!!This id has been recoreded.!!!!
# 266167  hasn't recorded
# Progress Rate: 2.11%1540468  hasn't recorded
# 1084416  hasn't recorded
# 1639625  hasn't recorded
# 4621513  hasn't recorded
# 4040600  hasn't recorded
# 1084416 !!!!This id has been recoreded.!!!!
# 560648  hasn't recorded
# 3579910  hasn't recorded
# 2307070  hasn't recorded
# 401656  hasn't recorded
# 2307070 !!!!This id has been recoreded.!!!!
# 2093695  hasn't recorded
# 5393381  hasn't recorded
# 4842742  hasn't recorded
# 2482744  hasn't recorded
# 1639625 !!!!This id has been recoreded.!!!!
# 5609344  hasn't recorded
# 541136  hasn't recorded
# Progress Rate: 3.16%1082449  hasn't recorded
# 4431955  hasn't recorded
# 603688  hasn't recorded
# 3763293  hasn't recorded
# 224132  hasn't recorded
# 87234  hasn't recorded
# 2684539  hasn't recorded
# 3422652  hasn't recorded
# 7917962  hasn't recorded
# 2684539 !!!!This id has been recoreded.!!!!
# 3422652 !!!!This id has been recoreded.!!!!
# 1774667  hasn't recorded
# 6418134  hasn't recorded
# 2378300  hasn't recorded
# 3422652 !!!!This id has been recoreded.!!!!
# 6418134 !!!!This id has been recoreded.!!!!
# 560648 !!!!This id has been recoreded.!!!!
# 6418134 !!!!This id has been recoreded.!!!!
# 1287251  hasn't recorded
# 5725780  hasn't recorded
# 3519004  hasn't recorded
# 1287251 !!!!This id has been recoreded.!!!!
# 3519004 !!!!This id has been recoreded.!!!!
# 3422652 !!!!This id has been recoreded.!!!!
# 7649016  hasn't recorded
# 7917962 !!!!This id has been recoreded.!!!!
# 3466415  hasn't recorded
# 1774667 !!!!This id has been recoreded.!!!!
# 6350858  hasn't recorded
# Progress Rate: 4.21%2079303  hasn't recorded
# 2912665  hasn't recorded
# 1505939  hasn't recorded
# 775806  hasn't recorded
# 5405086  hasn't recorded
# 103167  hasn't recorded
# API爆了
# 1505939 !!!!This id has been recoreded.!!!!
# 4672588  hasn't recorded
# API爆了
# 1505939 !!!!This id has been recoreded.!!!!
# 4672588 !!!!This id has been recoreded.!!!!
# 1505939 !!!!This id has been recoreded.!!!!
# 3867787  hasn't recorded
# API爆了
# 1505939 !!!!This id has been recoreded.!!!!
# 2580955  hasn't recorded
# API爆了
# 4451432  hasn't recorded
# API爆了
# 2580955 !!!!This id has been recoreded.!!!!
# 1505939 !!!!This id has been recoreded.!!!!
# 2079303 !!!!This id has been recoreded.!!!!
# 3867787 !!!!This id has been recoreded.!!!!
# 3867787 !!!!This id has been recoreded.!!!!
# 2079303 !!!!This id has been recoreded.!!!!
# 1505939 !!!!This id has been recoreded.!!!!
# 2079303 !!!!This id has been recoreded.!!!!
# Progress Rate: 5.26%1549818  hasn't recorded
# API爆了
# 23574  hasn't recorded
# API爆了
# 3141234  hasn't recorded
# API爆了
# 2023861  hasn't recorded
# API爆了
# 3393505  hasn't recorded
# API爆了
# 41071  hasn't recorded
# API爆了
# 4588915  hasn't recorded
# API爆了
# 706119  hasn't recorded
# API爆了
# 1433660  hasn't recorded
# API爆了
# 1436796  hasn't recorded
# API爆了
# 1436796 !!!!This id has been recoreded.!!!!
# 5386374  hasn't recorded
# API爆了
# 706119 !!!!This id has been recoreded.!!!!
# 1527  hasn't recorded
# API爆了
# 706119 !!!!This id has been recoreded.!!!!
# 1527 !!!!This id has been recoreded.!!!!
# 706119 !!!!This id has been recoreded.!!!!
# 6812179  hasn't recorded
# API爆了
# 1108505  hasn't recorded
# API爆了
# Progress Rate: 6.32%964243  hasn't recorded
# API爆了
# 29407  hasn't recorded
# API爆了
# 5053002  hasn't recorded
# API爆了
# 5459839  hasn't recorded
# API爆了
# 6241971  hasn't recorded
# API爆了
# 6419007  hasn't recorded
# API爆了
# 167735  hasn't recorded
# API爆了
# 167735 !!!!This id has been recoreded.!!!!
# 673852  hasn't recorded
# API爆了
# 995714  hasn't recorded
# API爆了
# 904812  hasn't recorded
# API爆了
# 2357112  hasn't recorded
# API爆了
# 5459839 !!!!This id has been recoreded.!!!!
# 446220  hasn't recorded
# API爆了
# 2404501  hasn't recorded
# API爆了
# 6419007 !!!!This id has been recoreded.!!!!
# 3402854  hasn't recorded
# API爆了
# 6419007 !!!!This id has been recoreded.!!!!
# Progress Rate: 7.37%5267169  hasn't recorded
# API爆了
# 6144478  hasn't recorded
# API爆了
# 5267169 !!!!This id has been recoreded.!!!!
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-1-4dfb3fb0a905> in <module>()
#     309         page=bs(requests.get(url).text,'html.parser')
# --> 310         right_ans=handleQ(page)
#     311         handleA(page,right_ans)
#
# <ipython-input-1-4dfb3fb0a905> in handleQ(page)
#     179         last_active_time=unixtodt(info['last_activity_date'])
# --> 180     users(ownerID)
#     181     add_question="INSERT INTO `stackOverflow`.`Questions` VALUES (NULL, '"+str(qID)+"', '"+FixText(title)+"', '"+tags+"', '"+ownerID+"', '"+score+"', '"+solved+"', '"+create_time+"', '"+last_active_time+"', '"+FixText(posts)+"');"
#
# <ipython-input-1-4dfb3fb0a905> in users(owner_id)
#      52     sql="SELECT `user_id`  FROM `User` WHERE `user_id` = "+str(owner_id)#把我從question抓下來的user_id，去User table找一樣的放進res
# ---> 53     cursor.execute(sql)
#      54     res=cursor.fetchall()
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     164
# --> 165         result = self._query(query)
#     166         self._executed = query
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     320         self._last_executed = q
# --> 321         conn.query(q)
#     322         self._do_get_result()
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     858                 sql = sql.encode(self.encoding, 'surrogateescape')
# --> 859         self._execute_command(COMMAND.COM_QUERY, sql)
#     860         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in _execute_command(self, command, sql)
#    1074         if not self._sock:
# -> 1075             raise err.InterfaceError("(0, '')")
#    1076
#
# InterfaceError: (0, '')
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-4dfb3fb0a905> in <module>()
#     315     except:
#     316         log='\nAn error occur at '+unixtodt(time.time())+'\n running qid: '+str(qID)+'\n'+str(sys.exc_info()[0])+'\n'+str(sys.exc_info()[1])+'\n Progress die.'
# --> 317         pen.write(log)
#     318         pen.close()
#     319         db.close()
#
# ValueError: I/O operation on closed file.
